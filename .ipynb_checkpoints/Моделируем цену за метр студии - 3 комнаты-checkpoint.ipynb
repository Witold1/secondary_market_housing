# %% [markdown]
# **Отчет 2: Влияние факторов на цену за метр у лотов**
# * Текст тут будет

# %% [markdown]
# #### Влияние ветки метро
# * Для измерения следует обработать данные по станциям, которые встречаются в более чем одной ветке. Например, станция Третьяковская по данным с портала открытых данных города Москвы ([ссылка](https://data.mos.ru/classifier/7704786030-stantsii-moskovskogo-metropolitena) расположена одновременно на трех ветках, одна из которых еще строится. Доступная выгрузка из источника данных не дает такой подробной информации.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.preprocessing import LabelEncoder
import statsmodels
PATH_TO_DATA = './data/'

from collections import defaultdict
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

import lightgbm as lgbm
import eli5
import scipy.stats
# Out:
# D:\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# D:\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Using TensorFlow backend.

# %%
df = pd.read_csv(PATH_TO_DATA + 'features_dataset.csv', index_col=[0])
target = pd.read_csv(PATH_TO_DATA + 'target_column.csv', index_col=[0])
print(df.shape)
print(f'{df.memory_usage().sum() / 1024 / 1024 :.2f} Mb')
assert df.shape[0] == target.shape[0]
# Out:
# (14329, 25)
# 1.98 Mb

# %%
df.nunique()
# Out:
# Округ                                 12
# Район                                153
# Площадь                             1736
# Площадь лог                         1736
# Кол-во комнат                          7
# Этаж                                  73
# Этажей в доме                         73
# Первый этаж                            2
# Последний этаж                         2
# Метро                                272
# Расстояние до метро (ед)              57
# Расстояние указано пешком              2
# Расстояние указано на транспорте       2
# Тип дома                               7
# Указан раздельный санузел              2
# Несколько санузлов                     2
# Балкон указан                          2
# Окна                                   3
# Окна во двор                           2
# Ремонт                                 4
# Наличие ремонта                        2
# Возраст дома                         126
# Доля жилой площади                  6121
# Доля куханной площади               5252
# Площадь кухни                        315
# dtype: int64

# %%
# df = df[~df['Кол-во комнат'].isin(['1', '2', '3', '4, ''5', 'МиСП'])]
df = df[df['Кол-во комнат'].isin(['1'])]
target = target.loc[df.index]

# %% [markdown]
# ### Предобрабатываем

# %% [markdown]
# > Закодируем категориальные признки (Округ, Район, Кол-во комнат, метро)

# %%
df.head(1)
# Out:
#   Округ          Район  Площадь  Площадь лог Кол-во комнат  Этаж  \
# 0   ВАО  р-н Гольяново     33.0     3.496508             1   9.0
#
#    Этажей в доме  Первый этаж  Последний этаж         Метро  ...  \
# 0            9.0        False            True  Первомайская  ...
#
#    Несколько санузлов  Балкон указан     Окна Окна во двор       Ремонт  \
# 0               False          False  Во двор         True  Без ремонта
#
#    Наличие ремонта  Возраст дома Доля жилой площади  Доля куханной площади  \
# 0            False          51.0           0.484848               0.212121
#
#   Площадь кухни
# 0           7.0
#
# [1 rows x 25 columns]

# %%
logging.info(f'Предобрабатываем: {df.columns[df.dtypes == "object"].values.tolist()}.')
label_encoder_dict = defaultdict(LabelEncoder)

df['Округ'] = df['Округ'].astype(str)
df['Район'] = df['Район'].astype(str)
df['Кол-во комнат'] = df['Кол-во комнат'].astype(str)
df['Метро'] = df['Метро'].astype(str)
df['Тип дома'] = df['Тип дома'].astype(str)
df['Окна'] = df['Окна'].astype(str)
df['Ремонт'] = df['Ремонт'].astype(str)

# df['Доля жилой площади'] = df['Доля жилой площади'].fillna(df.groupby('Кол-во комнат')['Доля жилой площади'].transform('median'))
# pd.get_dummies(df, columns=['Кол-во комнат', 'Метро', 'Тип дома', 'Окна', 'Ремонт'])
# df['Площадь'] = np.log(df['Площадь'])

cat_columns = df.columns[df.dtypes == 'object']
df[cat_columns] = df[cat_columns].apply(lambda x: label_encoder_dict[x.name].fit_transform(x)).astype('category')
# label_encoder_dict['Округ'].inverse_transform([8])
# df[cat_columns].apply(lambda x: label_encoder_dict[x.name].inverse_transform(x))

logging.info(f'Предобработка: завершение')
# Out:
# INFO:root:Предобрабатываем: ['Округ', 'Район', 'Кол-во комнат', 'Метро', 'Тип дома', 'Окна', 'Ремонт'].
# INFO:root:Предобработка: завершение

# %% [markdown]
# ### Моделируем

# %% [markdown]
# > Зависимость цены за метр^2 от признаков всех категорий жилья

# %%
def metrics_report(y_pred : np.array, y_true : np.array):
    '''
    Вывод метрик качества и графика рассеивания
    :input:
        predicted and background truth targets
    :return: 
        R2 and Mean Absolute Errors metrics values
    '''
    r2 = sklearn.metrics.r2_score(y_pred, y_true)
    mae = sklearn.metrics.mean_absolute_error(y_pred, y_true)
    mse = sklearn.metrics.mean_squared_error(y_pred, y_true)
    
    plt.scatter(y=y_pred, x=y_true, alpha=0.25);
    plt.ylabel('predicted log(Цена за метр^2)')
    plt.xlabel('log(Цена за метр^2)')
    plt.title('Диаграмма рассеивания (log(ˆp), log(p))')
    
    logging.info(f'R2 = {r2:.2f}; MAE = {mae:.2f}; MSE = {mse:.2f}')
    return r2, mae, mse

# %%
cols_not_to_use = ['Площадь', 'Площадь кухни']
target_col = 'Цена за метр^2'

logging.info(f'Моделируем: {target_col}.')
logging.info(f'Не используем: {cols_not_to_use}.')
logging.info(f'Используем: {list(df.columns[~df.columns.isin(cols_not_to_use)])}.')
# Out:
# INFO:root:Моделируем: Цена за метр^2.
# INFO:root:Не используем: ['Площадь', 'Площадь кухни'].
# INFO:root:Используем: ['Округ', 'Район', 'Площадь лог', 'Кол-во комнат', 'Этаж', 'Этажей в доме', 'Первый этаж', 'Последний этаж', 'Метро', 'Расстояние до метро (ед)', 'Расстояние указано пешком', 'Расстояние указано на транспорте', 'Тип дома', 'Указан раздельный санузел', 'Несколько санузлов', 'Балкон указан', 'Окна', 'Окна во двор', 'Ремонт', 'Наличие ремонта', 'Возраст дома', 'Доля жилой площади', 'Доля куханной площади'].

# %% [markdown]
# > * Студия: ```max_depth=7, n_estimators=100, num_leaves=12, reg_alpha=1.1, reg_beta=0.1, importance_type='split', random_state=42```

# %%
regressor = lgbm.LGBMRegressor(max_depth=7, n_estimators=100, 
                               num_leaves=12, reg_alpha=1.1, reg_beta=0.1,
                               importance_type='split', 
                               random_state=42)

# %%
regressor.fit(df.iloc[:, ~df.columns.isin(cols_not_to_use)], 
              np.log(target[target_col].values));
metrics_report(regressor.predict(df.iloc[:, ~df.columns.isin(cols_not_to_use)]),
               np.log(target[target_col].values));
# Out:
# INFO:root:R2 = 0.89; MAE = 0.06; MSE = 0.01

# %%
y = df.iloc[:, ~df.columns.isin(cols_not_to_use)].columns[regressor.feature_importances_.argsort()[::-1][:5]]
x = regressor.feature_importances_[regressor.feature_importances_.argsort()[::-1][:5]]
plt.barh(width=x, y=y);

# %%
eli5.explain_weights_lightgbm(regressor, vec=None, top=20, 
                         target_names=None, 
                         targets=None, 
                         feature_names=df.columns[~df.columns.isin(cols_not_to_use)].values, 
                         feature_re=None, 
                         feature_filter=None, 
                         importance_type='gain')
# Out:
# Explanation(estimator="LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,\n              importance_type='split', learning_rate=0.1, max_depth=7,\n              min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,\n              n_estimators=100, n_jobs=-1, num_leaves=12, objective=None,\n              random_state=42, reg_alpha=1.1, reg_beta=0.1, reg_lambda=0.0,\n              silent=True, subsample=1.0, subsample_for_bin=200000,\n              subsample_freq=0)", description='\nLightGBM feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='Район', weight=0.5452888647845298, std=None, value=None), FeatureWeight(feature='Округ', weight=0.11859898114464965, std=None, value=None), FeatureWeight(feature='Метро', weight=0.09014711853904048, std=None, value=None), FeatureWeight(feature='Площадь лог', weight=0.07474362950967631, std=None, value=None), FeatureWeight(feature='Этажей в доме', weight=0.033502692365115994, std=None, value=None), FeatureWeight(feature='Ремонт', weight=0.031851330870755146, std=None, value=None), FeatureWeight(feature='Возраст дома', weight=0.02945338947149727, std=None, value=None), FeatureWeight(feature='Расстояние до метро (ед)', weight=0.02088394795895467, std=None, value=None), FeatureWeight(feature='Доля куханной площади', weight=0.0148539565036883, std=None, value=None), FeatureWeight(feature='Доля жилой площади', weight=0.008297187336491922, std=None, value=None), FeatureWeight(feature='Расстояние указано пешком', weight=0.00807281997660301, std=None, value=None), FeatureWeight(feature='Расстояние указано на транспорте', weight=0.006158220817721338, std=None, value=None), FeatureWeight(feature='Этаж', weight=0.006100836009786866, std=None, value=None), FeatureWeight(feature='Тип дома', weight=0.005207954141191361, std=None, value=None), FeatureWeight(feature='Наличие ремонта', weight=0.0019419304422631897, std=None, value=None), FeatureWeight(feature='Указан раздельный санузел', weight=0.0015138135198478934, std=None, value=None), FeatureWeight(feature='Балкон указан', weight=0.0014587343783228736, std=None, value=None), FeatureWeight(feature='Окна', weight=0.0013558943802873863, std=None, value=None), FeatureWeight(feature='Несколько санузлов', weight=0.00026286012606014384, std=None, value=None), FeatureWeight(feature='Окна во двор', weight=0.0002607333846824025, std=None, value=None)], remaining=3), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
eli5.explain_weights_lightgbm(regressor, vec=None, top=20, 
                         target_names=None, 
                         targets=None, 
                         feature_names=df.columns[~df.columns.isin(cols_not_to_use)].values, 
                         feature_re=None, 
                         feature_filter=None, 
                         importance_type='split')
# Out:
# Explanation(estimator="LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,\n              importance_type='split', learning_rate=0.1, max_depth=7,\n              min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,\n              n_estimators=100, n_jobs=-1, num_leaves=12, objective=None,\n              random_state=42, reg_alpha=1.1, reg_beta=0.1, reg_lambda=0.0,\n              silent=True, subsample=1.0, subsample_for_bin=200000,\n              subsample_freq=0)", description='\nLightGBM feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='Площадь лог', weight=0.14727272727272728, std=None, value=None), FeatureWeight(feature='Район', weight=0.13363636363636364, std=None, value=None), FeatureWeight(feature='Округ', weight=0.11, std=None, value=None), FeatureWeight(feature='Возраст дома', weight=0.09363636363636364, std=None, value=None), FeatureWeight(feature='Доля куханной площади', weight=0.07545454545454545, std=None, value=None), FeatureWeight(feature='Этажей в доме', weight=0.07272727272727272, std=None, value=None), FeatureWeight(feature='Расстояние до метро (ед)', weight=0.060909090909090906, std=None, value=None), FeatureWeight(feature='Метро', weight=0.04909090909090909, std=None, value=None), FeatureWeight(feature='Ремонт', weight=0.046363636363636364, std=None, value=None), FeatureWeight(feature='Этаж', weight=0.04090909090909091, std=None, value=None), FeatureWeight(feature='Доля жилой площади', weight=0.04, std=None, value=None), FeatureWeight(feature='Тип дома', weight=0.02909090909090909, std=None, value=None), FeatureWeight(feature='Наличие ремонта', weight=0.019090909090909092, std=None, value=None), FeatureWeight(feature='Расстояние указано пешком', weight=0.017272727272727273, std=None, value=None), FeatureWeight(feature='Балкон указан', weight=0.017272727272727273, std=None, value=None), FeatureWeight(feature='Расстояние указано на транспорте', weight=0.015454545454545455, std=None, value=None), FeatureWeight(feature='Указан раздельный санузел', weight=0.015454545454545455, std=None, value=None), FeatureWeight(feature='Окна', weight=0.01090909090909091, std=None, value=None), FeatureWeight(feature='Несколько санузлов', weight=0.0018181818181818182, std=None, value=None), FeatureWeight(feature='Окна во двор', weight=0.0018181818181818182, std=None, value=None)], remaining=3), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
lgbm.plot_importance(regressor, figsize=(8, 5))
plt.tight_layout();

# %% [markdown]
# > Посмотрим на связь признаков
# * Корреляции Пирсона для количественным и Спирмана для качественных

# %% [markdown]
# * *Логорифм от площади, чтобы сгладить выбросы цены на графике и не удалять их*

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
plt.suptitle('Зависимости цены и цены за метр^2 (лог) от площади (лог)')
ax[0].scatter(x=np.log(target['Цена'].values), y=np.log(df['Площадь'].values), alpha=0.4)
ax[1].scatter(x=np.log(target['Цена за метр^2'].values), y=np.log(df['Площадь'].values), alpha=0.4)

ax[0].set_ylabel('Площадь (лог)')
ax[0].set_xlabel('Цена (лог)')
ax[1].set_xlabel('Цена за метр^2 (лог)')
# Out:
# Text(0.5, 0, 'Цена за метр^2 (лог)')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 5))
plt.suptitle('Зависимости цены и цены за метр^2 (лог) от числа комнат')
ax.scatter(x=np.log(target['Цена'].values), y=df['Кол-во комнат'].values, alpha=0.25, label='абсолютная')
ax.scatter(x=np.log(target['Цена за метр^2'].values), y=df['Кол-во комнат'].values, alpha=0.25, label='за м^2')
#plt.scatter(x=np.log(target['Цена за метр^2'].values), y=df['Кол-во комнат'].values, alpha=0.4)
ticks = [label_encoder_dict['Кол-во комнат'].inverse_transform([int(tick)])[0] for tick in plt.yticks()[0].tolist()[1:-1]]
plt.yticks(plt.yticks()[0], [''] + ticks + ['']);

ax.set_ylabel('Кол-во комнат')
ax.set_xlabel('Цена (лог)');
plt.legend()
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 5))
plt.suptitle('Зависимости площади от числа комнат')
ax.scatter(x=df['Площадь'].values, y=df['Кол-во комнат'].values, alpha=0.25)
ticks = [label_encoder_dict['Кол-во комнат'].inverse_transform([int(tick)])[0] for tick in plt.yticks()[0].tolist()[1:-1]]
plt.yticks(plt.yticks()[0], [''] + ticks + ['']);
ax.set_ylabel('Кол-во комнат')
ax.set_xlabel('Площадь');
ax.set_xlim(0, 350)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %% [markdown]
# Интересные характеристики лотов
# * Наличие более одного санузла, сильнее связано с площадью, чем с количеством комнат. А площадь уже связано с количеством комнат.
# * Число этажей обратно пропорционально возрасту дома. Наверное, это ожидаемо, при учете медианного возраста дома в $20$ лет ($18$ без обработки пропусков), а медианного количества этажей в доме равного $16$

# %%
scipy.stats.spearmanr(df['Кол-во комнат'].values, df['Несколько санузлов'].values)
# Out:
# C:\Users\Vitaly\AppData\Roaming\Python\Python37\site-packages\numpy\lib\function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Vitaly\AppData\Roaming\Python\Python37\site-packages\numpy\lib\function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# D:\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# D:\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# D:\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# SpearmanrResult(correlation=nan, pvalue=nan)

# %%
scipy.stats.spearmanr(df['Площадь'].values, df['Несколько санузлов'].values)
# Out:
# SpearmanrResult(correlation=0.14758191021873157, pvalue=1.4707461965854049e-12)

# %%
scipy.stats.spearmanr(df['Площадь'].values, df['Кол-во комнат'].values)
# Out:
# SpearmanrResult(correlation=nan, pvalue=nan)

# %%
scipy.stats.spearmanr(df['Этажей в доме'].values,
                      df['Возраст дома'].fillna(df.groupby(['Кол-во комнат'])['Возраст дома'].transform('median')))
# Out:
# SpearmanrResult(correlation=-0.5631412664544128, pvalue=1.0796237791764757e-190)

# %% [markdown]
# * Район сильнее связан как с абсолютной ценой, так и с ценой за метр квадратный, чем округ

# %%
scipy.stats.spearmanr(df['Район'].values, target.astype(int)['Цена'].values)
# Out:
# SpearmanrResult(correlation=0.28564495650879246, pvalue=5.223422163926198e-44)

# %%
scipy.stats.spearmanr(df['Метро'].values, target.astype(int)['Цена'].values)
# Out:
# SpearmanrResult(correlation=0.06959603187197351, pvalue=0.0008899609865509779)

# %% [markdown]
# * По не ясной причине, доля куханной площади обратно пропорционально площади. Возможно, дело в количестве пропусков и том, что мы не имеем полной картины

# %%
np.corrcoef(df['Площадь'].values, 
            df['Доля жилой площади'].fillna(df.groupby('Кол-во комнат')['Доля жилой площади'].transform('median')))
# Out:
# array([[ 1.        , -0.32504106],
#        [-0.32504106,  1.        ]])

# %%
np.corrcoef(df['Площадь'].values, 
            df['Доля куханной площади'].fillna(df.groupby('Кол-во комнат')['Доля куханной площади'].transform('median')))
# Out:
# array([[1.        , 0.16678853],
#        [0.16678853, 1.        ]])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax = sns.heatmap(df.corr(method='spearman'), linewidth=0.5, square=True,  cmap="YlGnBu")
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %% [markdown]
# > Также, на всякий случай рассмотрим качество модели на отложенной выборке

# %%
train_x, valid_x, train_y, valid_y = sklearn.model_selection.train_test_split(df.iloc[:, ~df.columns.isin(cols_not_to_use)], 
                                                                              np.log(target[target_col]), 
                                                                              test_size = 0.2, 
                                                                              shuffle = True, 
                                                                              stratify = df['Кол-во комнат'], 
                                                                              random_state = 891)
train_data = lgbm.Dataset(train_x, label=train_y)
valid_data = lgbm.Dataset(valid_x, label=valid_y)

# %%
params = {'metric' : 'mse',
          'boosting_type' : 'gbdt',
          'colsample_bytree' : 0.9234,
          'num_leaves' : 7,
          'max_depth' : 7,
          'n_estimators' : 8000,
          #'min_child_samples': 399, 
          #'min_child_weight': 0.1,
          'reg_alpha': 0.4,
          'reg_lambda': 2,
          'subsample': 0.855,
          'verbose' : 100,
          'num_threads' : 2}

# %%
#Train model on selected parameters and number of iterations
regressor_2 = lgbm.train(params,
                 train_data,
                 2500,
                 valid_sets = valid_data,
                 early_stopping_rounds = 120,
                 verbose_eval = 500
                 )
regressor_2.booster_ = regressor_2
# Out:
# D:\Anaconda\lib\site-packages\lightgbm\engine.py:116: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\Anaconda\lib\site-packages\lightgbm\basic.py:752: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 120 rounds.
# [500]	valid_0's l2: 0.013144
# Early stopping, best iteration is:
# [708]	valid_0's l2: 0.0130739

# %%
metrics_report(regressor_2.predict(valid_x), valid_y)
# Out:
# INFO:root:R2 = 0.81; MAE = 0.08; MSE = 0.01
# (0.8058518610396346, 0.08124847117236558, 0.013073916474122881)

# %%
eli5.explain_weights_lightgbm(regressor_2, vec=None, top=20, 
                         target_names=None, 
                         targets=None, 
                         feature_names=df.columns[~df.columns.isin(cols_not_to_use)].values, 
                         feature_re=None, 
                         feature_filter=None, 
                         importance_type='gain')
# Out:
# Explanation(estimator='<lightgbm.basic.Booster object at 0x000000F02BF0B780>', description='\nLightGBM feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='Район', weight=0.37220978476490324, std=None, value=None), FeatureWeight(feature='Округ', weight=0.2220963499992555, std=None, value=None), FeatureWeight(feature='Метро', weight=0.08776330668203003, std=None, value=None), FeatureWeight(feature='Площадь лог', weight=0.0801166288274666, std=None, value=None), FeatureWeight(feature='Возраст дома', weight=0.039745539971105096, std=None, value=None), FeatureWeight(feature='Этажей в доме', weight=0.03922971030440151, std=None, value=None), FeatureWeight(feature='Доля куханной площади', weight=0.03573640849893559, std=None, value=None), FeatureWeight(feature='Ремонт', weight=0.02709839364268929, std=None, value=None), FeatureWeight(feature='Доля жилой площади', weight=0.02188274257427016, std=None, value=None), FeatureWeight(feature='Расстояние указано пешком', weight=0.021814847251383166, std=None, value=None), FeatureWeight(feature='Расстояние до метро (ед)', weight=0.019918710103973065, std=None, value=None), FeatureWeight(feature='Этаж', weight=0.00829693447211332, std=None, value=None), FeatureWeight(feature='Расстояние указано на транспорте', weight=0.007097396845194906, std=None, value=None), FeatureWeight(feature='Тип дома', weight=0.005563583285124156, std=None, value=None), FeatureWeight(feature='Окна', weight=0.00239336125354647, std=None, value=None), FeatureWeight(feature='Наличие ремонта', weight=0.002327555119597564, std=None, value=None), FeatureWeight(feature='Указан раздельный санузел', weight=0.0019822991645904574, std=None, value=None), FeatureWeight(feature='Балкон указан', weight=0.0019670726789363024, std=None, value=None), FeatureWeight(feature='Несколько санузлов', weight=0.0018508738032180687, std=None, value=None), FeatureWeight(feature='Последний этаж', weight=0.0005116824407966729, std=None, value=None)], remaining=3), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
eli5.explain_weights_lightgbm(regressor_2, vec=None, top=20, 
                         target_names=None, 
                         targets=None, 
                         feature_names=df.columns[~df.columns.isin(cols_not_to_use)].values, 
                         feature_re=None, 
                         feature_filter=None, 
                         importance_type='split')
# Out:
# Explanation(estimator='<lightgbm.basic.Booster object at 0x000000F02BF0B780>', description='\nLightGBM feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='Доля куханной площади', weight=0.12900188323917136, std=None, value=None), FeatureWeight(feature='Площадь лог', weight=0.11275894538606403, std=None, value=None), FeatureWeight(feature='Возраст дома', weight=0.11064030131826742, std=None, value=None), FeatureWeight(feature='Доля жилой площади', weight=0.09745762711864407, std=None, value=None), FeatureWeight(feature='Район', weight=0.09274952919020715, std=None, value=None), FeatureWeight(feature='Округ', weight=0.07886064030131827, std=None, value=None), FeatureWeight(feature='Расстояние до метро (ед)', weight=0.07509416195856874, std=None, value=None), FeatureWeight(feature='Этажей в доме', weight=0.06497175141242938, std=None, value=None), FeatureWeight(feature='Этаж', weight=0.06261770244821092, std=None, value=None), FeatureWeight(feature='Метро', weight=0.062146892655367235, std=None, value=None), FeatureWeight(feature='Ремонт', weight=0.029661016949152543, std=None, value=None), FeatureWeight(feature='Окна', weight=0.021657250470809793, std=None, value=None), FeatureWeight(feature='Тип дома', weight=0.019303201506591337, std=None, value=None), FeatureWeight(feature='Балкон указан', weight=0.010828625235404897, std=None, value=None), FeatureWeight(feature='Расстояние указано пешком', weight=0.007297551789077213, std=None, value=None), FeatureWeight(feature='Указан раздельный санузел', weight=0.006826741996233522, std=None, value=None), FeatureWeight(feature='Расстояние указано на транспорте', weight=0.005885122410546139, std=None, value=None), FeatureWeight(feature='Наличие ремонта', weight=0.005178907721280603, std=None, value=None), FeatureWeight(feature='Последний этаж', weight=0.003295668549905838, std=None, value=None), FeatureWeight(feature='Несколько санузлов', weight=0.0018832391713747645, std=None, value=None)], remaining=3), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
lgbm.plot_importance(regressor_2, importance_type='split', figsize=(8, 5))
plt.tight_layout()

# %% [markdown]
# > Посмотрим на еще один способ изучить значимость признаков
# * SHAP

# %%
import shap

# %%
# %time
# https://www.kaggle.com/dansbecker/advanced-uses-of-shap-values
# https://blog.datascienceheroes.com/how-to-interpret-shap-values-in-r/
# https://towardsdatascience.com/explain-any-models-with-the-shap-values-use-the-kernelexplainer-79de9464897a
explainer = shap.TreeExplainer(regressor)
shap_values = explainer.shap_values(df.iloc[:, ~df.columns.isin(cols_not_to_use)])
shap.summary_plot(shap_values, df.iloc[:, ~df.columns.isin(cols_not_to_use)])
# Out:
# Wall time: 0 ns

# %%
shap.dependence_plot("Округ", shap_values, df.iloc[:, ~df.columns.isin(cols_not_to_use)])

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, 
                shap_values[0:1], 
                df.iloc[:, ~df.columns.isin(cols_not_to_use)][0:1])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# <div id='i5MWS8SNMQKVJYNOAA63N'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 12.1780576686433, "outValue": 12.098295289809032, "link": "identity", "featureNames": ["\u041e\u043a\u0440\u0443\u0433", "\u0420\u0430\u0439\u043e\u043d", "\u041f\u043b\u043e\u0449\u0430\u0434\u044c \u043b\u043e\u0433", "\u041a\u043e\u043b-\u0432\u043e \u043a\u043e\u043c\u043d\u0430\u0442", "\u042d\u0442\u0430\u0436", "\u042d\u0442\u0430\u0436\u0435\u0439 \u0432 \u0434\u043e\u043c\u0435", "\u041f\u0435\u0440\u0432\u044b\u0439 \u044d\u0442\u0430\u0436", "\u041f\u043e\u0441\u043b\u0435\u0434\u043d\u0438\u0439 \u044d\u0442\u0430\u0436", "\u041c\u0435\u0442\u0440\u043e", "\u0420\u0430\u0441\u0441\u0442\u043e\u044f\u043d\u0438\u0435 \u0434\u043e \u043c\u0435\u0442\u0440\u043e (\u0435\u0434)", "\u0420\u0430\u0441\u0441\u0442\u043e\u044f\u043d\u0438\u0435 \u0443\u043a\u0430\u0437\u0430\u043d\u043e \u043f\u0435\u0448\u043a\u043e\u043c", "\u0420\u0430\u0441\u0441\u0442\u043e\u044f\u043d\u0438\u0435 \u0443\u043a\u0430\u0437\u0430\u043d\u043e \u043d\u0430 \u0442\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442\u0435", "\u0422\u0438\u043f \u0434\u043e\u043c\u0430", "\u0423\u043a\u0430\u0437\u0430\u043d \u0440\u0430\u0437\u0434\u0435\u043b\u044c\u043d\u044b\u0439 \u0441\u0430\u043d\u0443\u0437\u0435\u043b", "\u041d\u0435\u0441\u043a\u043e\u043b\u044c\u043a\u043e \u0441\u0430\u043d\u0443\u0437\u043b\u043e\u0432", "\u0411\u0430\u043b\u043a\u043e\u043d \u0443\u043a\u0430\u0437\u0430\u043d", "\u041e\u043a\u043d\u0430", "\u041e\u043a\u043d\u0430 \u0432\u043e \u0434\u0432\u043e\u0440", "\u0420\u0435\u043c\u043e\u043d\u0442", "\u041d\u0430\u043b\u0438\u0447\u0438\u0435 \u0440\u0435\u043c\u043e\u043d\u0442\u0430", "\u0412\u043e\u0437\u0440\u0430\u0441\u0442 \u0434\u043e\u043c\u0430", "\u0414\u043e\u043b\u044f \u0436\u0438\u043b\u043e\u0439 \u043f\u043b\u043e\u0449\u0430\u0434\u0438", "\u0414\u043e\u043b\u044f \u043a\u0443\u0445\u0430\u043d\u043d\u043e\u0439 \u043f\u043b\u043e\u0449\u0430\u0434\u0438"], "features": {"0": {"effect": -0.006347913141328756, "value": 0}, "1": {"effect": -0.0564743413072444, "value": 47}, "2": {"effect": 0.05871298772117383, "value": 3.49650756146648}, "4": {"effect": 0.004107892683570748, "value": 9.0}, "5": {"effect": -0.008788878708116787, "value": 9.0}, "7": {"effect": -0.0005988685123953852, "value": true}, "8": {"effect": -0.002475408427948212, "value": 136}, "9": {"effect": -0.014197476715328502, "value": 15.0}, "10": {"effect": 0.006588941380604166, "value": true}, "11": {"effect": 0.0039021267249615675, "value": false}, "12": {"effect": 0.007560053683317642, "value": 4}, "13": {"effect": 0.001346462433276446, "value": false}, "14": {"effect": -0.00024704584942581006, "value": false}, "15": {"effect": -0.011281704764534446, "value": false}, "16": {"effect": -0.0031712343189045492, "value": 1}, "17": {"effect": -0.0003576861032561576, "value": true}, "18": {"effect": -0.024543135229338223, "value": 1}, "19": {"effect": -0.013505924038424707, "value": false}, "20": {"effect": -0.011297534590465503, "value": 51.0}, "21": {"effect": 0.0005050629861152234, "value": 0.4848484848484849}, "22": {"effect": -0.009198754740575906, "value": 0.21212121212121213}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i5MWS8SNMQKVJYNOAA63N')
#   );
# </script>

# %%
df.iloc[:, :][0:1]
# Out:
#   Округ Район  Площадь  Площадь лог Кол-во комнат  Этаж  Этажей в доме  \
# 0     0    47     33.0     3.496508             0   9.0            9.0
#
#    Первый этаж  Последний этаж Метро  ...  Несколько санузлов  Балкон указан  \
# 0        False            True   136  ...               False          False
#
#    Окна Окна во двор  Ремонт  Наличие ремонта  Возраст дома  \
# 0     1         True       1            False          51.0
#
#   Доля жилой площади  Доля куханной площади Площадь кухни
# 0           0.484848               0.212121           7.0
#
# [1 rows x 25 columns]

# %%
label_encoder_dict['Кол-во комнат'].inverse_transform([0])
# Out:
# array(['1'], dtype=object)

# %%
label_encoder_dict['Округ'].inverse_transform([0])
# Out:
# array(['ВАО'], dtype=object)

# %%
label_encoder_dict['Метро'].inverse_transform([159])
# Out:
# array(['Речной вокзал'], dtype=object)
